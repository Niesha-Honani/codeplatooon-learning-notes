# %% [markdown]
# Day 5 : JEST
# 1. Install Jest using NPM
# 2. update package.json to run tests using jest
# 3. update package.json for any specific test specs i.e. look for /tests etc.
#
# Assignment Fibonacci
# 1. write FibCode
# 2. Run tests
#
# n= 0
# num1 = 1
#
# f(i=1) = 1 + n  = 1
# n=1
# f(i=2) =  0+1 = 1
# n = 1
# f(i=3) = 1+1 = 2
# n=2
# f(4) = 3
# n = 3
# f(5) = 2 + 3 = 5
# f(6) = 5+3 = 8
# f(7) = 13
#
# num1 =
#
# for loop 6-1
# for (let i = 1 ; i = num-1(5)){
#     num1
# }
# for (let i = 1; i = num ; i++){
#     num2
# }
# return num1+num2
