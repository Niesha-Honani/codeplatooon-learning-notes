# %%
🧠 Concept: What git init and “upstream” actually do
Command	Purpose	When You Use It
git init	Initializes a new local Git repository (creates a .git folder).	When starting a brand new project that doesn’t exist yet on GitHub or anywhere else.
git remote add origin <URL>	Links your local repo to a remote GitHub repo.	After git init, so Git knows where to push/pull from.
git push --set-upstream origin <branch>	Sets the upstream tracking branch for your current local branch.	When your branch doesn’t have a remote tracking branch yet.
🚫 Why You can’t replace git init with setting an upstream

You must already have a Git repo (created by git init or git clone) before you can set an upstream branch.

If you haven’t run git init or git clone, you don’t even have a .git folder — so Git doesn’t know what “branch” or “remote” means yet.

Think of it like this:

🔧 git init = Create the toolbox
🔗 git remote add origin = Tell Git where your cloud toolbox is
🚀 git push --set-upstream origin my-branch = Sync your local tool with its cloud version

✅ Example Workflow (for a new branch)

If you already have a repo set up (either cloned or initialized):

# 1. Create a new branch locally
git checkout -b feature/new-feature

# 2. Make your changes and commit them
git add .
git commit -m "Add new feature"

# 3. Push and set upstream tracking
git push --set-upstream origin feature/new-feature


After that, you can just use:

git push
git pull


and Git will automatically know where to send and fetch changes for that branch.

🧩 Quick check if you have an upstream set
git branch -vv


You’ll see something like:

* feature/new-feature  abc123 [origin/feature/new-feature] Add new feature


If there’s no [origin/... ], then no upstream is set yet.
