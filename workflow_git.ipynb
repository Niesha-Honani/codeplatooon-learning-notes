# %% [markdown]
# ## Dail Workflow per fork / repo
#
# git status
# git add .
# git commit -m "Assignment commit notes"
# git push origin <branch>
#
# ## Make PR from fork -> class repo
#
# Make new assignment repo
# 1. Fork assignment from Code Platoon
# 2. Clone fork into CodePlatoon <working directory - not a repo>
#
# * Every assignment is it's own repo
# * No nesting inside another git repo
#
# Rename my own repo
# cd /current_repo
# mv current_repo new_name
